# %%
# prompt: Design a class BankAccount that represents a bank account using encapsulation. The class should include:A private attribute  _balance to store the account balance.
# A static variable total_accounts to keep track of the total number of bank accounts created.
# Methods:
# __init__(self, initial_balance=0): Initializes the account with a starting balance and updates the static variable total_accounts. Ensure the initial balance is non-negative.
# set_balance(self, new_balance): Allows modifying the balance, but ensures the balance cannot be set to a negative value.
# deposit(self, amount): Adds the specified amount to the balance. Ensure the amount is positive.
# withdraw(self, amount): Withdraws the specified amount from the balance.

class BankAccount:
    total_accounts = 0

    def __init__(self, initial_balance=0):
        if initial_balance < 0:
            raise ValueError("Initial balance cannot be negative.")
        self._balance = initial_balance
        BankAccount.total_accounts += 1

    def set_balance(self, new_balance):
        if new_balance < 0:
            raise ValueError("Balance cannot be negative.")
        self._balance = new_balance

    def deposit(self, amount):
        if amount <= 0:
            raise ValueError("Deposit amount must be positive.")
        self._balance += amount

    def withdraw(self, amount):
        if amount <= 0:
            raise ValueError("Withdrawal amount must be positive.")
        if amount > self._balance:
            raise ValueError("Insufficient funds.")
        self._balance -= amount

    def get_balance(self): #added getter method for balance
      return self._balance

# %%
# prompt: Design a class Student that represents a student. The class should have:Private attributes called name, age and a static variable GPA.The class should include:
# __init__(self, name, age): Initializes the student's name and age.
# add_subject_grade(self, subject, grade,credits): Adds a grade for a subject and updates the static GPA.
# get_gpa(self): Returns the current GPA.
# get_name(self): Returns the student's name.
# get_age(self): Returns the student's age.
# Hints: GPA = sum of all (grades*credits)​ / total number of credits

class Student:
    total_marks = 0
    total_credits = 0
    GPA = 0

    def __init__(self, name, age):
        self.__name = name
        self.__age = age
        Student.total_students += 1
        self.__subjects = {} # Dictionary to store subject grades

    def add_subject_grade(self, subject, grade, credits):
        Student.total_marks += grade * credits

        Student.total_credits += credits


    def get_gpa(self):
        Student.GPA = Student.total_marks / Student.total_credits
        return Student.GPA

    def get_name(self):
        return self.__name

    def get_age(self):
        return self.__age
