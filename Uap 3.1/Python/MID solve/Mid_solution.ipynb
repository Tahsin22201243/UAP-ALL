# %%
# prompt: Develop a Python function that takes a dictionary as a positional argument, where the keys are student names and the values are lists of their marks in different subjects. The function should return a new dictionary with student names as keys and their total marks as values. You do not have to take the inputs from users. You should call the function with the required parameter.
# Function call
# Function returns
# students_marks = {
#     ‘Meena’: [85, 90, 78],
#     'Raju': [80, 88, 92],
#    ‘Mithu’: [90, 85, 85]
# }
# fun(students_marks )
# {
#     'Meena': 253,
#    ‘Raju’: 260,
#    ‘Mithu’: 260
# }

def fun(students_marks):
  total_marks = {}
  for student, marks in students_marks.items():
    total_marks[student] = sum(marks)
  return total_marks


students_marks = {
    'Meena': [85, 90, 78],
    'Raju': [80, 88, 92],
    'Mithu': [90, 85, 85]
}

result = fun(students_marks)
result

# %%
# Out:
#   File "<ipython-input-2-597d1e299ca6>", line 9
#     output = fun(key: sum(value))
#                     ^
# SyntaxError: invalid syntax

# %%
# prompt: Develop a basic calculator in Python that prompts the user to select an arithmetic operation. Afterward, request the user to input two numbers, and then perform the chosen operation (addition, subtraction, multiplication, or division) on the given numbers.
# *  Make sure to handle division by zero error
# Sample Input
# Sample output
# Enter operation: add
# Enter number 1 : 10
# Enter number 2 : 5
# The result is: 15

def calculate():
  operation = input("Enter operation (add, subtract, multiply, divide): ")
  num1 = float(input("Enter number 1: "))
  num2 = float(input("Enter number 2: "))

  if operation == "add":
    result = num1 + num2
  elif operation == "subtract":
    result = num1 - num2
  elif operation == "multiply":
    result = num1 * num2
  elif operation == "divide":
    if num2 == 0:
      print("Error: Division by zero")
      return
    result = num1 / num2
  else:
    print("Invalid operation.")
    return

  print("The result is:", result)


calculate()

# %%
# prompt: Assess the following figure and write an HTML code that includes the following elements as shown:
# An h1 heading that says "Me after seeing the question paper."
# An image of a cat, the file name is cat.jpg .
# A form with the text "How do you feel?" followed by three radio buttons (only one should be selectable):
# The first option should be labeled "Panic."
# The second option should be labeled "Cry."
# The third option should be labeled "Laugh."
# Include a submit button that shows an alert with the message "You chose your reaction!" when clicked.

<!DOCTYPE html>
<html>
<head>
<title>Reaction to Question Paper</title>
</head>
<body>

<h1>Me after seeing the question paper.</h1>

<img src="cat.jpg" alt="Cat Image">

<form>
  <p>How do you feel?</p>
  <input type="radio" name="reaction">
  <label>Panic</label><br>
  <input type="radio" name="reaction">
  <label>Cry</label><br>
  <input type="radio"  name="reaction">
  <label>Laugh</label><br><br>
  <button type="button">Submit</button>
</form>

</body>
</html>

# %%
# prompt: Imagine you’re building a payroll system for a company. Each employee has basic details like their name, position, and salary. The system should also be able to calculate bonuses based on a percentage of their salary.
# (a) Create a Python class named Employee with attributes name, position, and salary.
# (b) Add a method called calculate_bonus() that takes a bonus_percentage as an argument and returns the total salary including the bonus.
# (c) Create an Employee object and use the calculate_bonus() method to calculate the employee’s total salary after applying a bonus of 10%.

class Employee:
  def __init__(self, name, position, salary):
    self.name = name
    self.position = position
    self.salary = salary

  def calculate_bonus(self, bonus_percentage):
    bonus_amount = self.salary * (bonus_percentage / 100)
    total_salary = self.salary + bonus_amount
    return total_salary


# Create an Employee object
employee = Employee("John Doe", "Software Engineer", 60000)

# Calculate the total salary with a 10% bonus
total_salary_with_bonus = employee.calculate_bonus(10)

# Print the result
print(f"Total salary with bonus: {total_salary_with_bonus}")
