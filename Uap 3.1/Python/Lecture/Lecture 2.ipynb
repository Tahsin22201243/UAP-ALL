# %% [markdown]
# ## Basic operation

# %%
print("Hello class")
# Out:
# Hello class

# %%
print(hello world)
# Out:
#   File "<ipython-input-2-6135c6da936c>", line 1
#     print(hello world)
#           ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
hello
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-f572d396fae9> in <cell line: 1>()
# ----> 1 hello
#
# NameError: name 'hello' is not defined

# %%
print('1'+'1')
# Out:
# 11

# %%
print("My name is : Progga")
# Out:
# My name is : Progga

# %%
print("My id is: ",1)
# Out:
# My id is:  1

# %%
print("I am ",30, "years old")
# Out:
# I am  30 years old

# %%
print("This is my class\nClass code is CSE 309")
# Out:
# This is my class
# Class code is CSE 309

# %%
words = 'Hello.world'
print(words)
result = words.split()
print(result)
# Out:
# Hello.world
# ['Hello.world']

# %%
spilt_string = words[-1]
print(spilt_string)
# Out:
# d

# %%
print(words[10] == words[-1])
# Out:
# True

# %%
list1= [1,2,3.76,'hello']
print(list1)
# Out:
# [1, 2, 3.76, 'hello']

# %%
print(list1[0])
# Out:
# 1

# %%
print(list1[-100])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-786a71397d54> in <cell line: 1>()
# ----> 1 print(list1[-100])
#
# IndexError: list index out of range

# %%
print(list1[1:3])
# Out:
# [2, 3.76]

# %%
list1.append(2)
print(list1)
# Out:
# [1, 2, 3.76, 'hello', 2]

# %%
list1.insert(999,'y')
print(list1)

# %%
list1.append('sharif')
print(list1)

# %%
popped_item = list1.pop()
print(popped_item)

# %%
print(list1.pop())

# %%
print(list1.pop() == list1[-1])

# %%
print(list1)

# %%
print(list1.pop())
print(list1[-1])

# %%
print(list1[-1] == list1.pop())
